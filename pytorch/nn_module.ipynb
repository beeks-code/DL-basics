# %%
import torch
import torch.nn as nn

# %%
class NeuralNetwork(nn.modules):
    def __init__(self,features):
        super().__init__()
        self.linear=nn.Linear(features,i)
        self.sigmoid=nn.Sigmoid()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-715179676.py in <cell line: 0>()
# ----> 1 class NeuralNetwork(nn.modules):
#       2     def __init__(self,features):
#       3         super().__init__()
#       4         self.linear=nn.Linear(features,i)
#       5         self.sigmoid=nn.Sigmoid()
#
# TypeError: module() takes at most 2 arguments (3 given)
